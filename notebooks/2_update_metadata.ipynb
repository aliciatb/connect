# %% [markdown]
# ## Exercise 2. Update Metadata on a Dataset
# Let's use the [Metadata API](https://socratametadataapi.docs.apiary.io/#) to add more information to our dataset.
#
# ## Import Libraries

# %%
import json
import os
import pandas as pd
import requests

# %% [markdown]
# ## Setup Authentication
# ### Enter Education Credentials
#
# Also, it is pow possible to set up API Keys and pass key id and secret values as Socrata user name and password or [api keys](https://socrataapikeys.docs.apiary.io) respectively

# %%
domain = 'macondointernal.demo.socrata.com'

user_name = ''
password = ''

# how you would pass credentials stored in environment variables
# user_name = os.environ['SOCRATA_KEY_ID']
# password = os.environ['SOCRATA_KEY_SECRET']

# Enter dataset id created from Exercise 1
dataset_id = 'nump-7qcy'

# URL to metadata for any asset
meta_url = 'https://' + domain + '/api/views/metadata/v1/' + dataset_id

dataset_description = 'Median Household Income - American Community Survey 5 Year Estimates for all Arizona Places from 2011-2017'

# %% [markdown]
# ## Make HTTP request for existing metadata
# - Include authentication because dataset is private by default

# %%
req = requests.get(meta_url, auth=(user_name,password))

meta = req.text
print(meta)
# Out:
# {
#   "id" : "nump-7qcy",
#   "name" : "Arizona Places Median Household Income",
#   "attribution" : null,
#   "attributionLink" : null,
#   "category" : null,
#   "createdAt" : "2019-04-08T00:22:30+0000",
#   "dataUpdatedAt" : "2019-04-08T00:23:16+0000",
#   "dataUri" : "https://macondointernal.demo.socrata.com/resource/nump-7qcy",
#   "description" : "source = pandas",
#   "domain" : "macondointernal.demo.socrata.com",
#   "externalId" : null,
#   "hideFromCatalog" : false,
#   "hideFromDataJson" : false,
#   "license" : null,
#   "metadataUpdatedAt" : "2019-04-08T00:23:15+0000",
#   "provenance" : "OFFICIAL",
#   "updatedAt" : "2019-04-08T00:23:15+0000",
#   "webUri" : "https://macondointernal.demo.socrata.com/d/nump-7qcy",
#   "approvals" : [ {
#     "notes" : "",
#     "state" : "pending",
#     "submissionId" : 343475,
#     "submissionObject" : "public_audience_request",
#     "submissionOutcome" : "change_audience",
#     "submittedAt" : 1554682997,
#     "workflowId" : 504,
#     "submissionDetails" : {
#       "permissionType" : "READ"
#     },
#     "submitter" : {
#       "id" : "2wgn-e7yp",
#       "displayName" : "Student 1",
#       "email" : "1@socrata.edu"
#     }
#   } ],
#   "customFields" : null,
#   "tags" : null
# }

# %% [markdown]
# ## Make HTTP Patch request to update dataset description
# - Create the JSON and encode it

# %%
# update Description using Patch method which allows updates for selected properties
payload = {"description": dataset_description}
json_data = json.dumps(payload)

req_update = requests.patch(meta_url, json_data, auth=(user_name,password))
meta_new = req_update.text
print(meta_new)
# Out:
# {
#   "action" : "modify",
#   "metadata" : {
#     "id" : "nump-7qcy",
#     "name" : "Arizona Places Median Household Income",
#     "attribution" : null,
#     "attributionLink" : null,
#     "category" : null,
#     "createdAt" : "2019-04-08T00:22:30+0000",
#     "dataUpdatedAt" : "2019-04-08T00:23:16+0000",
#     "dataUri" : "https://macondointernal.demo.socrata.com/resource/nump-7qcy",
#     "description" : "Median Household Income - American Community Survey 5 Year Estimates for all Arizona Places from 2011-2017",
#     "domain" : "macondointernal.demo.socrata.com",
#     "externalId" : null,
#     "hideFromCatalog" : false,
#     "hideFromDataJson" : false,
#     "license" : null,
#     "metadataUpdatedAt" : "2019-04-08T00:34:33+0000",
#     "provenance" : "OFFICIAL",
#     "updatedAt" : "2019-04-08T00:34:33+0000",
#     "webUri" : "https://macondointernal.demo.socrata.com/d/nump-7qcy",
#     "approvals" : [ {
#       "notes" : "",
#       "state" : "pending",
#       "submissionId" : 343475,
#       "submissionObject" : "public_audience_request",
#       "submissionOutcome" : "change_audience",
#       "submittedAt" : 1554682997,
#       "workflowId" : 504,
#       "submissionDetails" : {
#         "permissionType" : "READ"
#       },
#       "submitter" : {
#         "id" : "2wgn-e7yp",
#         "displayName" : "Student 1",
#         "email" : "1@socrata.edu"
#       }
#     } ],
#     "customFields" : null,
#     "tags" : null
#   }
# }

# %% [markdown]
# ## Update multiple metadata properties by iterating through a file
# - `/data/dataset_metadata.xlsx` contains dataset id and other metadata properties for a dataset that can be suitable  for bulk updates
# - Set NaNs to blanks
#
# Let's update https://alicia.data.socrata.com/dataset/Arizona-Places-Median-Household-Income/9abs-ubh5 with many properties.

# %%
metadata = pd.read_excel('../data/dataset_metadata.xlsx')
metadata = metadata.fillna('')
metadata.head()
# Out:
#   dataset_id                                    name      category  \
# 0  nump-7qcy  Arizona Places Median Household Income  Demographics
# 1  ebv5-4bfy  Arizona Places Median Household Income      Business
# 2  cfvy-xet3  Arizona Places Median Household Income  Demographics
#
#                                          description attribution  \
# 0  Median Household Income - American Community S...      Census
# 1  Median Household Income - American Community S...      Census
# 2  Median Household Income - American Community S...
#
#                                 attributionLink  \
# 0  https://www.census.gov/programs-surveys/acs/
# 1  https://www.census.gov/programs-surveys/acs/
# 2
#
#                                    tags
# 0
# 1                                income
# 2  income, household income, prosperity

# %%
for idx,row in metadata.iterrows():
    dataset_id = row['dataset_id']
    meta_url = 'https://' + domain + '/api/views/metadata/v1/' + dataset_id
    
    payload = dict()
    payload['name'] = row['name']
    payload['description'] = row['description']
    payload['category'] = row['category']

    # if there are multiple keywords, split them by comma
    if(row['tags'] != ''):
        payload['tags'] = row['tags'].split(',')
    else:
        payload['tags'] = []
    
    # empty links return validation error
    if(row['attributionLink']!=''):
        payload['attributionLink'] = row['attributionLink']
    
    # encode json
    json_data = json.dumps(payload)
    # print(json_data)
    
    req_update = requests.patch(meta_url, json_data, auth=(user_name,password))
    meta_new = req_update.text
    print(meta_new)
# Out:
# {
#   "action" : "modify",
#   "metadata" : {
#     "id" : "nump-7qcy",
#     "name" : "Arizona Places Median Household Income",
#     "attribution" : null,
#     "attributionLink" : "https://www.census.gov/programs-surveys/acs/",
#     "category" : "Demographics",
#     "createdAt" : "2019-04-08T00:22:30+0000",
#     "dataUpdatedAt" : "2019-04-08T00:23:16+0000",
#     "dataUri" : "https://macondointernal.demo.socrata.com/resource/nump-7qcy",
#     "description" : "Median Household Income - American Community Survey 5 Year Estimates for all Arizona Places from 2011-2017",
#     "domain" : "macondointernal.demo.socrata.com",
#     "externalId" : null,
#     "hideFromCatalog" : false,
#     "hideFromDataJson" : false,
#     "license" : null,
#     "metadataUpdatedAt" : "2019-04-08T00:38:24+0000",
#     "provenance" : "OFFICIAL",
#     "updatedAt" : "2019-04-08T00:38:24+0000",
#     "webUri" : "https://macondointernal.demo.socrata.com/d/nump-7qcy",
#     "approvals" : [ {
#       "notes" : "",
#       "state" : "pending",
#       "submissionId" : 343475,
#       "submissionObject" : "public_audience_request",
#       "submissionOutcome" : "change_audience",
#       "submittedAt" : 1554682997,
#       "workflowId" : 504,
#       "submissionDetails" : {
#         "permissionType" : "READ"
#       },
#       "submitter" : {
#         "id" : "2wgn-e7yp",
#         "displayName" : "Student 1",
#         "email" : "1@socrata.edu"
#       }
#     } ],
#     "customFields" : null,
#     "tags" : null
#   }
# }
#
# {
#   "action" : "modify",
#   "metadata" : {
#     "id" : "ebv5-4bfy",
#     "name" : "Arizona Places Median Household Income",
#     "attribution" : null,
#     "attributionLink" : "https://www.census.gov/programs-surveys/acs/",
#     "category" : "Business",
#     "createdAt" : "2019-04-08T00:22:18+0000",
#     "dataUpdatedAt" : "2019-04-08T00:22:27+0000",
#     "dataUri" : "https://macondointernal.demo.socrata.com/resource/ebv5-4bfy",
#     "description" : "Median Household Income - American Community Survey 5 Year Estimates for all Arizona Places from 2011-2017",
#     "domain" : "macondointernal.demo.socrata.com",
#     "externalId" : null,
#     "hideFromCatalog" : false,
#     "hideFromDataJson" : false,
#     "license" : null,
#     "metadataUpdatedAt" : "2019-04-08T00:38:25+0000",
#     "provenance" : "OFFICIAL",
#     "updatedAt" : "2019-04-08T00:38:25+0000",
#     "webUri" : "https://macondointernal.demo.socrata.com/d/ebv5-4bfy",
#     "approvals" : [ {
#       "notes" : "",
#       "state" : "pending",
#       "submissionId" : 343473,
#       "submissionObject" : "public_audience_request",
#       "submissionOutcome" : "change_audience",
#       "submittedAt" : 1554682948,
#       "workflowId" : 504,
#       "submissionDetails" : {
#         "permissionType" : "READ"
#       },
#       "submitter" : {
#         "id" : "2wgn-e7yp",
#         "displayName" : "Student 1",
#         "email" : "1@socrata.edu"
#       }
#     } ],
#     "customFields" : null,
#     "tags" : [ "income" ]
#   }
# }
#
# {
#   "action" : "modify",
#   "metadata" : {
#     "id" : "cfvy-xet3",
#     "name" : "Arizona Places Median Household Income",
#     "attribution" : null,
#     "attributionLink" : null,
#     "category" : "Demographics",
#     "createdAt" : "2019-04-08T00:37:10+0000",
#     "dataUpdatedAt" : "2019-04-08T00:37:49+0000",
#     "dataUri" : "https://macondointernal.demo.socrata.com/resource/cfvy-xet3",
#     "description" : "Median Household Income - American Community Survey 5 Year Estimates for all Arizona Places from 2011-2017",
#     "domain" : "macondointernal.demo.socrata.com",
#     "externalId" : null,
#     "hideFromCatalog" : false,
#     "hideFromDataJson" : false,
#     "license" : null,
#     "metadataUpdatedAt" : "2019-04-08T00:38:25+0000",
#     "provenance" : "OFFICIAL",
#     "updatedAt" : "2019-04-08T00:38:25+0000",
#     "webUri" : "https://macondointernal.demo.socrata.com/d/cfvy-xet3",
#     "approvals" : [ {
#       "notes" : "",
#       "state" : "pending",
#       "submissionId" : 343477,
#       "submissionObject" : "public_audience_request",
#       "submissionOutcome" : "change_audience",
#       "submittedAt" : 1554683869,
#       "workflowId" : 504,
#       "submissionDetails" : {
#         "permissionType" : "READ"
#       },
#       "submitter" : {
#         "id" : "2wgn-e7yp",
#         "displayName" : "Student 1",
#         "email" : "1@socrata.edu"
#       }
#     } ],
#     "customFields" : null,
#     "tags" : [ "income", "household income", "prosperity" ]
#   }
# }
